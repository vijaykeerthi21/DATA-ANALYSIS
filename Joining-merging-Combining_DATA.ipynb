# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaykeerthi21/DATA-ANALYSIS/blob/main/Joining-merging-Combining_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_ISRO1 = pd.DataFrame({
    "ISRO_PROJECTS" :["Chandrayaan-1","Chandrayaan-2","Chandrayaan-3","Aditya-L1"],
    "PROJECT_DATES" :["22 October 2008","22 July 2019","22 July 2019","2 September 2023"],
    "PROJECT_STATUS" :["Successful","Successful","Successful","Successful"]
})
df1
# Out:
#    ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS
# 0  Chandrayaan-1   22 October 2008     Successful
# 1  Chandrayaan-2      22 July 2019     Successful
# 2  Chandrayaan-3      22 July 2019     Successful
# 3      Aditya-L1  23 November 2022     Successful

# %%
df_ISRO2 = pd.DataFrame({
    "ISRO_PROJECTS" :["Chandrayaan-1","Chandrayaan-2","Chandrayaan-3","Gaganyaaan"],
    "ROCKET_TYPE" :["PSLV-XL","GSLV-M3","GSLV-Mk3","HSLV-M3"],
    "PROJECT_PLACE" :["Bangalore","Bangalore","Bangalore","TBA"]


})
df2
# Out:
#    ISRO_PROJECTS ROCKET_TYPE PROJECT_PLACE
# 0  Chandrayaan-1     PSLV-XL     Bangalore
# 1  Chandrayaan-2     GSLV-M3     Bangalore
# 2  Chandrayaan-3    GSLV-Mk3     Bangalore
# 3     Gaganyaaan     HSLV-M3           TBA

# %% [markdown]
# Joining and merging of DataFrames

# %%
#Inner joint
#it is the intersection of common elements present in both dataframes
df3 = pd.merge(df_ISRO1, df_ISRO2, on ="ISRO_PROJECTS",how="inner")
df3
# Out:
#    ISRO_PROJECTS    PROJECT_DATES PROJECT_STATUS ROCKET_TYPE PROJECT_PLACE
# 0  Chandrayaan-1  22 October 2008     Successful     PSLV-XL     Bangalore
# 1  Chandrayaan-2     22 July 2019     Successful     GSLV-M3     Bangalore
# 2  Chandrayaan-3     22 July 2019     Successful    GSLV-Mk3     Bangalore

# %%
#Outer joint
#It is the intersection of all elements present in both dataframes
df4 = pd.merge(df_ISRO1, df_ISRO2, on ="ISRO_PROJECTS", how="outer")
df4
# Out:
#    ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS ROCKET_TYPE PROJECT_PLACE
# 0  Chandrayaan-1   22 October 2008     Successful     PSLV-XL     Bangalore
# 1  Chandrayaan-2      22 July 2019     Successful     GSLV-M3     Bangalore
# 2  Chandrayaan-3      22 July 2019     Successful    GSLV-Mk3     Bangalore
# 3      Aditya-L1  23 November 2022     Successful         NaN           NaN
# 4     Gaganyaaan               NaN            NaN     HSLV-M3           TBA

# %%
#left joint
#It is the intersection of left side(df_ISRO1) elements in dataframes
df6 = pd.merge(df_ISRO1, df_ISRO2, on ="ISRO_PROJECTS", how="left")
df6
# Out:
#    ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS ROCKET_TYPE PROJECT_PLACE
# 0  Chandrayaan-1   22 October 2008     Successful     PSLV-XL     Bangalore
# 1  Chandrayaan-2      22 July 2019     Successful     GSLV-M3     Bangalore
# 2  Chandrayaan-3      22 July 2019     Successful    GSLV-Mk3     Bangalore
# 3      Aditya-L1  23 November 2022     Successful         NaN           NaN

# %%
#Right joint
#It is the intersection of Right side(df_ISRO2)elements in dataframes
df7 = pd.merge(df_ISRO1, df_ISRO2, on ="ISRO_PROJECTS", how="right")
df7
# Out:
#    ISRO_PROJECTS    PROJECT_DATES PROJECT_STATUS ROCKET_TYPE PROJECT_PLACE
# 0  Chandrayaan-1  22 October 2008     Successful     PSLV-XL     Bangalore
# 1  Chandrayaan-2     22 July 2019     Successful     GSLV-M3     Bangalore
# 2  Chandrayaan-3     22 July 2019     Successful    GSLV-Mk3     Bangalore
# 3     Gaganyaaan              NaN            NaN     HSLV-M3           TBA

# %% [markdown]
# Combining Data

# %%
df_ISRO3 = pd.DataFrame({
    "ISRO_PROJECTS" :["Chandrayaan-1","Chandrayaan-2","Chandrayaan-3","Aditya-L1","Gaganyaaan"],
    "PROJECT_DATES" :["22 October 2008","22 July 2019","22 July 2019","2 September 2023","TBA"],
   "PROJECT_STATUS" :["Successful","Successful","Successful","Successful","  "],
    "ROCKET_TYPE" :["PSLV-XL","GSLV-M3","GSLV-Mk3","PSLV-C57","HSLV-M3"],
    "PROJECT_PLACE" :["SDSC SHAR","SDSC SHAR","SDSC SHAR","SDSC SHAR","TBA"]


})
df_ISRO3
# Out:
#    ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS ROCKET_TYPE PROJECT_PLACE
# 0  Chandrayaan-1   22 October 2008     Successful     PSLV-XL     SDSC SHAR
# 1  Chandrayaan-2      22 July 2019     Successful     GSLV-M3     SDSC SHAR
# 2  Chandrayaan-3      22 July 2019     Successful    GSLV-Mk3     SDSC SHAR
# 3      Aditya-L1  2 September 2023     Successful    PSLV-C57     SDSC SHAR
# 4     Gaganyaaan               TBA                    HSLV-M3           TBA

# %%
df_NASA = pd.DataFrame({
    "NASA_PROJECTS" :["Voyager-1","Voyager-2","Apollo-11"],
    "PROJECT_DATES" :["5 September 1977","20 August 1977","16 July 1969",],
    "PROJECT_STATUS" :["Successful","Successful","Successful"],
    "ROCKET_TYPE" :["Titan-Centaur","Titan IIIE","Saturn V "],
    "PROJECT_PLACE" :["Cape Canaveral","Cape Canaveral","Cape Kennedy "]


})
df_NASA
# Out:
#   NASA_PROJECTS     PROJECT_DATES PROJECT_STATUS    ROCKET_TYPE  \
# 0     Voyager-1  5 September 1977     Successful  Titan-Centaur
# 1     Voyager-2    20 August 1977     Successful     Titan IIIE
# 2     Apollo-11      16 July 1969     Successful      Saturn V
#
#     PROJECT_PLACE
# 0  Cape Canaveral
# 1  Cape Canaveral
# 2   Cape Kennedy

# %%
#It is the COMBINATION of all elements present in both dataframes
df = pd.concat([df_ISRO3, df_NASA], ignore_index=True)
df
# Out:
#    ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS    ROCKET_TYPE  \
# 0  Chandrayaan-1   22 October 2008     Successful        PSLV-XL
# 1  Chandrayaan-2      22 July 2019     Successful        GSLV-M3
# 2  Chandrayaan-3      22 July 2019     Successful       GSLV-Mk3
# 3      Aditya-L1  2 September 2023     Successful       PSLV-C57
# 4     Gaganyaaan               TBA                       HSLV-M3
# 5            NaN  5 September 1977     Successful  Titan-Centaur
# 6            NaN    20 August 1977     Successful     Titan IIIE
# 7            NaN      16 July 1969     Successful      Saturn V
#
#     PROJECT_PLACE NASA_PROJECTS
# 0       SDSC SHAR           NaN
# 1       SDSC SHAR           NaN
# 2       SDSC SHAR           NaN
# 3       SDSC SHAR           NaN
# 4             TBA           NaN
# 5  Cape Canaveral     Voyager-1
# 6  Cape Canaveral     Voyager-2
# 7   Cape Kennedy      Apollo-11

# %%
#TO NAME the data frames separatly
df_1 = pd.concat([df_ISRO3, df_NASA], keys=["ISRO","NASA"])

df_1
# Out:
#         ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS    ROCKET_TYPE  \
# ISRO 0  Chandrayaan-1   22 October 2008     Successful        PSLV-XL
#      1  Chandrayaan-2      22 July 2019     Successful        GSLV-M3
#      2  Chandrayaan-3      22 July 2019     Successful       GSLV-Mk3
#      3      Aditya-L1  2 September 2023     Successful       PSLV-C57
#      4     Gaganyaaan               TBA                       HSLV-M3
# NASA 0            NaN  5 September 1977     Successful  Titan-Centaur
#      1            NaN    20 August 1977     Successful     Titan IIIE
#      2            NaN      16 July 1969     Successful      Saturn V
#
#          PROJECT_PLACE NASA_PROJECTS
# ISRO 0       SDSC SHAR           NaN
#      1       SDSC SHAR           NaN
#      2       SDSC SHAR           NaN
#      3       SDSC SHAR           NaN
#      4             TBA           NaN
# NASA 0  Cape Canaveral     Voyager-1
#      1  Cape Canaveral     Voyager-2
# ...

# %%
#TO accses the data using new key
df_1.loc["ISRO"]
# Out:
#    ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS ROCKET_TYPE PROJECT_PLACE  \
# 0  Chandrayaan-1   22 October 2008     Successful     PSLV-XL     SDSC SHAR
# 1  Chandrayaan-2      22 July 2019     Successful     GSLV-M3     SDSC SHAR
# 2  Chandrayaan-3      22 July 2019     Successful    GSLV-Mk3     SDSC SHAR
# 3      Aditya-L1  2 September 2023     Successful    PSLV-C57     SDSC SHAR
# 4     Gaganyaaan               TBA                    HSLV-M3           TBA
#
#   NASA_PROJECTS
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df_1.loc["NASA"]
# Out:
#   ISRO_PROJECTS     PROJECT_DATES PROJECT_STATUS    ROCKET_TYPE  \
# 0           NaN  5 September 1977     Successful  Titan-Centaur
# 1           NaN    20 August 1977     Successful     Titan IIIE
# 2           NaN      16 July 1969     Successful      Saturn V
#
#     PROJECT_PLACE NASA_PROJECTS
# 0  Cape Canaveral     Voyager-1
# 1  Cape Canaveral     Voyager-2
# 2   Cape Kennedy      Apollo-11

# %%
#NEW column with data
s = pd.Series(["Successful","Successful","Successful"],name ="STATUS")

# %%
#Combining the new data to the dataframe
MAIN_DF= pd.concat([df_NASA,s], axis=1)
MAIN_DF
# Out:
#   NASA_PROJECTS     PROJECT_DATES PROJECT_STATUS    ROCKET_TYPE  \
# 0     Voyager-1  5 September 1977     Successful  Titan-Centaur
# 1     Voyager-2    20 August 1977     Successful     Titan IIIE
# 2     Apollo-11      16 July 1969     Successful      Saturn V
#
#     PROJECT_PLACE      STATUS
# 0  Cape Canaveral  Successful
# 1  Cape Canaveral  Successful
# 2   Cape Kennedy   Successful
