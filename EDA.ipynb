# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaykeerthi21/DATA-ANALYSIS/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("auction[1].csv")

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
print(df)
# Out:
#                     PLAYER NATIONALITY         TYPE                 TEAM  \
# 0           Daryl Mitchell    Overseas  All-Rounder  Chennai Super Kings
# 1             Sameer Rizvi      Indian       Batter  Chennai Super Kings
# 2           Shardul Thakur      Indian  All-Rounder  Chennai Super Kings
# 3        Mustafizur Rahman    Overseas       Bowler  Chennai Super Kings
# 4          Rachin Ravindra    Overseas  All-Rounder  Chennai Super Kings
# ..                     ...         ...          ...                  ...
# 67             Travis Head    Overseas       Batter  Sunrisers Hyderabad
# 68          Jaydev Unadkat      Indian       Bowler  Sunrisers Hyderabad
# 69       Wanindu Hasaranga    Overseas  All-Rounder  Sunrisers Hyderabad
# 70  Jhathavedh Subramanyan      Indian       Bowler  Sunrisers Hyderabad
# 71             Akash Singh      Indian       Bowler  Sunrisers Hyderabad
#
#     PRICE PAID
# 0    140000000
# 1     84000000
# 2     40000000
# 3     20000000
# ...

# %%
df.shape
#Returns Number of(Row and Columns)
# Out:
# (72, 5)

# %%
#To access first 5 rows of data from dataframe(df)
df.head()
# Out:
#               PLAYER NATIONALITY         TYPE                 TEAM  PRICE PAID
# 0     Daryl Mitchell    Overseas  All-Rounder  Chennai Super Kings   140000000
# 1       Sameer Rizvi      Indian       Batter  Chennai Super Kings    84000000
# 2     Shardul Thakur      Indian  All-Rounder  Chennai Super Kings    40000000
# 3  Mustafizur Rahman    Overseas       Bowler  Chennai Super Kings    20000000
# 4    Rachin Ravindra    Overseas  All-Rounder  Chennai Super Kings    18000000

# %%
#To access LAST 5 rows of data from dataframe(df)
df.tail()
# Out:
#                     PLAYER NATIONALITY         TYPE                 TEAM  \
# 67             Travis Head    Overseas       Batter  Sunrisers Hyderabad
# 68          Jaydev Unadkat      Indian       Bowler  Sunrisers Hyderabad
# 69       Wanindu Hasaranga    Overseas  All-Rounder  Sunrisers Hyderabad
# 70  Jhathavedh Subramanyan      Indian       Bowler  Sunrisers Hyderabad
# 71             Akash Singh      Indian       Bowler  Sunrisers Hyderabad
#
#     PRICE PAID
# 67    68000000
# 68    16000000
# 69    15000000
# 70     2000000
# 71     2000000

# %%
#To access ANY RANDOM VALUE OF  rows of data from dataframe(df)
df.sample(3)
# Out:
#              PLAYER NATIONALITY         TYPE                 TEAM  PRICE PAID
# 45    Anshul Kamboj      Indian  All-Rounder       Mumbai Indians     2000000
# 44  Shivalik Sharma      Indian  All-Rounder       Mumbai Indians     2000000
# 0    Daryl Mitchell    Overseas  All-Rounder  Chennai Super Kings   140000000

# %%
#To access ANY RANDOM VALUE OF rows of data IN TRANSPOSED from dataframe(df)
df.sample(3).T
# Out:
#                              50              39              12
# PLAYER       Tanay Thyagarajann  Gerald Coetzee      Ricky Bhui
# NATIONALITY              Indian        Overseas          Indian
# TYPE                All-Rounder     All-Rounder   Wicket-Keeper
# TEAM               Punjab Kings  Mumbai Indians  Delhi Capitals
# PRICE PAID              2000000        50000000         2000000

# %%
#It gives a brief about data in df
#ex : column names, null values,count,data_types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYER       72 non-null     object
#  1   NATIONALITY  72 non-null     object
#  2   TYPE         72 non-null     object
#  3   TEAM         72 non-null     object
#  4   PRICE PAID   72 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.9+ KB

# %%
#To check DATA TYPES
df.dtypes
# Out:
# PLAYER         object
# NATIONALITY    object
# TYPE           object
# TEAM           object
# PRICE PAID      int64
# dtype: object

# %%
#To check NUMBER OF ENTERS PRESENT IN MENTIONED COLUMN
df.TEAM.nunique()
# Out:
# 10

# %%
#To check NUMBER OF ENTERS PRESENT IN MENTIONED COLUMN
df.TYPE.nunique()
# Out:
# 4

# %%
#To check NAMES OF ENTERS PRESENT IN MENTIONED COLUMN
df.TEAM.unique()
# Out:
# array(['Chennai Super Kings', 'Delhi Capitals', 'Gujarat Titans',
#        'Kolkata Knight Riders', 'Lucknow Super Giants', 'Mumbai Indians',
#        'Punjab Kings', 'Rajasthan Royals', 'Royal Challengers Bengaluru',
#        'Sunrisers Hyderabad'], dtype=object)

# %%
#To check NAMES OF ENTERS PRESENT IN MENTIONED COLUMN
df.TYPE.unique()
# Out:
# array(['All-Rounder', 'Batter', 'Bowler', 'Wicket-Keeper'], dtype=object)

# %%
#To check NAMES OF ENTERS PRESENT IN MENTIONED COLUMN
df.NATIONALITY.unique()
# Out:
# array(['Overseas', 'Indian'], dtype=object)

# %%
#To see the name of the columns in df
df.columns
# Out:
# Index(['PLAYER', 'NATIONALITY', 'TYPE', 'TEAM', 'PRICE PAID'], dtype='object')

# %%
#TO KNOW THE COUNT IN SPECIFIED COLUMN
df.TEAM.value_counts(dropna = False)
# Out:
# TEAM
# Kolkata Knight Riders          10
# Delhi Capitals                  9
# Gujarat Titans                  8
# Mumbai Indians                  8
# Punjab Kings                    8
# Chennai Super Kings             6
# Lucknow Super Giants            6
# Royal Challengers Bengaluru     6
# Sunrisers Hyderabad             6
# Rajasthan Royals                5
# Name: count, dtype: int64

# %%
df.TYPE.value_counts(dropna = False)
# Out:
# TYPE
# Bowler           26
# All-Rounder      25
# Batter           13
# Wicket-Keeper     8
# Name: count, dtype: int64

# %%
df.NATIONALITY.value_counts(dropna = False)
# Out:
# NATIONALITY
# Indian      42
# Overseas    30
# Name: count, dtype: int64

# %%
#IN specific column the sum of another integer type column
df.groupby(['TYPE'],as_index= False)['PRICE PAID'].sum().sort_values(by='PRICE PAID',ascending = False)
# Out:
#             TYPE  PRICE PAID
# 2         Bowler   940500000
# 0    All-Rounder   788500000
# 1         Batter   442000000
# 3  Wicket-Keeper   133500000

# %%
df.groupby(['NATIONALITY'],as_index= False)['PRICE PAID'].sum().sort_values(by='PRICE PAID',ascending = False)
# Out:
#   NATIONALITY  PRICE PAID
# 1    Overseas  1510000000
# 0      Indian   794500000

# %%
df.groupby(['TEAM'],as_index= False)['PRICE PAID'].sum().sort_values(by='PRICE PAID',ascending = False)
# Out:
#                           TEAM  PRICE PAID
# 3        Kolkata Knight Riders   313500000
# 9          Sunrisers Hyderabad   308000000
# 0          Chennai Super Kings   304000000
# 2               Gujarat Titans   303000000
# 6                 Punjab Kings   249500000
# 8  Royal Challengers Bengaluru   204000000
# 1               Delhi Capitals   190500000
# 5               Mumbai Indians   167000000
# 7             Rajasthan Royals   143000000
# 4         Lucknow Super Giants   122000000

# %%
#Statistics on Numeric Columns
df.describe()
# Out:
#          PRICE PAID
# count  7.200000e+01
# mean   3.200694e+07
# std    4.659788e+07
# min    2.000000e+06
# 25%    2.000000e+06
# 50%    1.250000e+07
# 75%    4.850000e+07
# max    2.475000e+08

# %%
#Statistics on object Columns
df.describe(include = 'object')
# Out:
#                 PLAYER NATIONALITY    TYPE                   TEAM
# count               72          72      72                     72
# unique              72           2       4                     10
# top     Daryl Mitchell      Indian  Bowler  Kolkata Knight Riders
# freq                 1          42      26                     10

# %% [markdown]
# Conclusion : This is how we can Explore and Analysis the Data,Exploratory Data Analysis(EDA)
